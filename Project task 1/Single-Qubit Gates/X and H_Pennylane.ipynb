# %%
# !pip install PennyLane
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 24.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.5/15.5 MB 34.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 25.4 MB/s eta 0:00:00
# ...

# %%
import pennylane as qml
import numpy as np

# %% [markdown]
# # Codercise I.4.1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
dev = qml.device("default.qubit", wires=1)

U = np.array([[1, 1], [1, -1]]) / np.sqrt(2)


@qml.qnode(dev)
def varied_initial_state(state):
    """Complete the function such that we can apply the operation U to
    either |0> or |1> depending on the input argument flag.

    Args:
        state (int): Either 0 or 1. If 1, prepare the qubit in state |1>,
            otherwise, leave it in state 0.

    Returns:
        np.array[complex]: The state of the qubit after the operations.
    """
    ##################
    if state == 1:
        qml.PauliX(wires=0)
    ##################

    # KEEP THE QUBIT IN |0> OR CHANGE IT TO |1> DEPENDING ON THE state PARAMETER
    qml.QubitUnitary(U,wires=0)
    # APPLY U TO THE STATE

    return qml.state()

# %% [markdown]
# ## Learnt how to use the PauliX gate and how to flip the bits based on the input using the same.

# %% [markdown]
# # Codercise I.4.2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
dev = qml.device("default.qubit", wires=1)


@qml.qnode(dev)
def apply_hadamard():
    ##################
    # YOUR CODE HERE #
    ##################

    # APPLY THE HADAMARD GATE
    qml.Hadamard(wires=0)

    # RETURN THE STATE
    return qml.state()

# %% [markdown]
# ## Learnt how to apply the hadamard state using Pennylane

# %% [markdown]
# # Codercise I.4.3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
dev = qml.device("default.qubit", wires=1)

@qml.qnode(dev)
def apply_hadamard_to_state(state):
    """Complete the function such that we can apply the Hadamard to
    either |0> or |1> depending on the input argument flag.

    Args:
        state (int): Either 0 or 1. If 1, prepare the qubit in state |1>,
            otherwise, leave it in state 0.

    Returns:
        np.array[complex]: The state of the qubit after the operations.
    """
    ##################
    # YOUR CODE HERE #
    ##################

    # KEEP THE QUBIT IN |0> OR CHANGE IT TO |1> DEPENDING ON state

    # APPLY THE HADAMARD
    if state ==1:
        qml.X(wires=0)

    qml.Hadamard(wires=0)

    # RETURN THE STATE

    return qml.state()


print(apply_hadamard_to_state(0))
print(apply_hadamard_to_state(1))
# Out:
# [0.70710678+0.j 0.70710678+0.j]
# [ 0.70710678+0.j -0.70710678+0.j]

# %% [markdown]
# ## Learnt how to apply the Hadamard and PauliX gate and use the X gate based on input.

# %% [markdown]
# # Codercise I.4.4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# CREATE A DEVICE
dev = qml.device("default.qubit", wires=1)

# CREATE A QNODE CALLED apply_hxh THAT APPLIES THE CIRCUIT ABOVE

@qml.qnode(dev)
def apply_hxh(state):

    if state == 1:
        qml.PauliX(wires=0)

    qml.Hadamard(wires=0)
    qml.PauliX(wires=0)
    qml.Hadamard(wires=0)

    # RETURN THE STATE
    return qml.state()

# Print your results
print(apply_hxh(0))
print(apply_hxh(1))
# Out:
# [1.+0.j 0.+0.j]
# [ 0.+0.j -1.+0.j]

# %% [markdown]
# ## Learnt how to write a QNode from scratch and apply the above circuit comprising of PauliX and Hadamard gates
