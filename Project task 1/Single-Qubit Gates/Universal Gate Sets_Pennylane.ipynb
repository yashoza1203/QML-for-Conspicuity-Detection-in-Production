# %%
# !pip install PennyLane
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 29.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.5/15.5 MB 52.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 59.0 MB/s eta 0:00:00
# ...

# %%
import pennylane as qml
import numpy as np

# %% [markdown]
# # Codercise I.7.1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
dev = qml.device("default.qubit", wires=1)

##################
# YOUR CODE HERE #
##################

# ADJUST THE VALUES OF PHI, THETA, AND OMEGA
phi, theta, omega = np.pi /2, np.pi/2, np.pi/2


@qml.qnode(dev)
def hadamard_with_rz_rx():
    qml.RZ(phi, wires=0)
    qml.RX(theta, wires=0)
    qml.RZ(omega, wires=0)
    return qml.state()

# %% [markdown]
# ## Learnt how to define the different angles for RZ,RX gates to form the Rot gate

# %% [markdown]
# # Codercise I.7.2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
dev = qml.device("default.qubit", wires=1)


@qml.qnode(dev)
def convert_to_rz_rx():
    ##################
    # YOUR CODE HERE #
    ##################

    # IMPLEMENT THE CIRCUIT IN THE PICTURE USING ONLY RZ AND RX
    qml.RZ(np.pi/2, wires=0)
    qml.RX(np.pi/2, wires=0)
    qml.RZ(np.pi/2, wires=0)

    qml.RZ(np.pi / 2, wires=0)

    qml.RZ(-np.pi / 4, wires=0)

    qml.RZ(-np.pi / 2, wires=0)
    qml.RX(np.pi, wires=0)
    qml.RZ(np.pi / 2, wires=0)

    return qml.state()

# %% [markdown]
# ## Learnt how to form the above circuit using just RX,RZ gates

# %% [markdown]
# # Codercise I.7.3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
dev = qml.device("default.qubit", wires=1)


@qml.qnode(dev)
def convert_to_rz_rx():
    ##################
    # YOUR CODE HERE #
    ##################

    # IMPLEMENT THE CIRCUIT IN THE PICTURE USING ONLY RZ AND RX
    qml.RZ(np.pi/2, wires=0)
    qml.RX(np.pi/2, wires=0)
    qml.RZ(np.pi/2, wires=0)

    qml.RZ(np.pi / 2, wires=0)

    qml.RZ(-np.pi / 4, wires=0)

    qml.RZ(-np.pi / 2, wires=0)
    qml.RX(np.pi, wires=0)
    qml.RZ(np.pi / 2, wires=0)

    return qml.state()

# %% [markdown]
# ## Learnt how to form a pennylane circuit using just Hadamard and T gates.
